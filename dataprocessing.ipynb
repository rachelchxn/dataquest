# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
def dayOfYear(month, day, year):
    daysInMonth = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    dayOfYear = sum(daysInMonth[:int(month)-1]) + int(day)
    if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0) and dayOfYear > 59:
        dayOfYear -= 1
    return dayOfYear

# %%
def preprocessing(df):
    
    df['ArrivalDayOfYear'] = df.apply(lambda row: dayOfYear(row['ArrivalMonth'], row['ArrivalDate'], row['ArrivalYear']), axis=1)
    
    df['TotalNights'] = df['NumWeekendNights'] + df['NumWeekNights']

    df['TotalGuests'] = df['NumAdults'] + df['NumChildren']
    
    df['TotalPrice'] = df['AvgRoomPrice'] * df['TotalNights']

# %%
df = pd.read_csv('test_data_mod.csv')
preprocessing(df)

# %%
df
# Out:
#       BookingID  LeadTime  ArrivalYear  ArrivalMonth  ArrivalDate  \
# 0         29020       211         2018             5           20
# 1         29021       121         2018             7            6
# 2         29022        30         2018            11           26
# 3         29023       256         2018             6           15
# 4         29024       122         2018            11           25
# ...         ...       ...          ...           ...          ...
# 7250      36270        65         2018             7           27
# 7251      36271        28         2018             9           18
# 7252      36272       116         2018             2           28
# 7253      36273       148         2018             7            1
# 7254      36274        63         2018             4           21
#
#       NumWeekendNights  NumWeekNights      MealPlan  Parking     RoomType  \
# 0                    0              2   Meal Plan 1        0  Room_Type 1
# 1                    0              4   Meal Plan 1        0  Room_Type 1
# 2                    2              1  Not Selected        0  Room_Type 1
# 3                    0              2   Meal Plan 2        0  Room_Type 1
# 4                    0              1   Meal Plan 1        0  Room_Type 1
# ...                ...            ...           ...      ...          ...
# 7250                 0              3   Meal Plan 1        0  Room_Type 6
# 7251                 2              0   Meal Plan 1        0  Room_Type 1
# 7252                 2              1   Meal Plan 1        0  Room_Type 1
# 7253                 2              6   Meal Plan 1        0  Room_Type 1
# 7254                 0              3  Not Selected        0  Room_Type 1
#
#       ...  RepeatedGuest  NumPrevCancellations NumPreviousNonCancelled  \
# 0     ...              0                     0                       0
# 1     ...              0                     0                       0
# 2     ...              0                     0                       0
# 3     ...              0                     0                       0
# 4     ...              0                     0                       0
# ...   ...            ...                   ...                     ...
# 7250  ...              0                     0                       0
# 7251  ...              0                     0                       0
# 7252  ...              0                     0                       0
# 7253  ...              0                     0                       0
# 7254  ...              0                     0                       0
#
#       AvgRoomPrice  SpecialRequests  BookingStatus  ArrivalDayOfYear  \
# 0           100.00                0            NaN               140
# 1            96.90                1            NaN               187
# 2            88.00                0            NaN               330
# 3           115.00                1            NaN               166
# 4            67.00                0            NaN               329
# ...            ...              ...            ...               ...
# 7250        177.30                0            NaN               208
# 7251        149.00                1            NaN               261
# 7252          1.00                0            NaN                59
# 7253         98.39                2            NaN               182
# 7254         94.50                0            NaN               111
#
#       TotalNights  TotalGuests  TotalPrice
# 0               2            2      200.00
# 1               4            3      387.60
# 2               3            2      264.00
# 3               2            2      230.00
# 4               1            1       67.00
# ...           ...          ...         ...
# 7250            3            4      531.90
# 7251            2            2      298.00
# 7252            3            1        3.00
# 7253            8            2      787.12
# 7254            3            2      283.50
#
# [7255 rows x 23 columns]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
