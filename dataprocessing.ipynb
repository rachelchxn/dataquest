# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
def dayOfYear(month, day, year):
    daysInMonth = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    dayOfYear = sum(daysInMonth[:int(month)-1]) + int(day)
    if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0) and dayOfYear > 59:
        dayOfYear -= 1
    return dayOfYear

# %%
def preprocessing(df):
    
    # df['ArrivalDayOfYear'] = df.apply(lambda row: dayOfYear(row['ArrivalMonth'], row['ArrivalDate'], row['ArrivalYear']), axis=1)
    df['ArrivalMonth'] = df['ArrivalMonth']/12
    df['ArrivalDate'] = df['ArrivalDate']/30
    
    # df['TotalNights'] = df['NumWeekendNights'] + df['NumWeekNights']

    # df['TotalGuests'] = df['NumAdults'] + df['NumChildren']
    
    # df['TotalPrice'] = df['AvgRoomPrice'] * df['TotalNights']

# %%
df = pd.read_csv('test_data_mod.csv')
preprocessing(df)

# %%
df
# Out:
#       BookingID  LeadTime  ArrivalYear  ArrivalMonth  ArrivalDate  \
# 0         29020       211         2018      0.416667     0.666667
# 1         29021       121         2018      0.583333     0.200000
# 2         29022        30         2018      0.916667     0.866667
# 3         29023       256         2018      0.500000     0.500000
# 4         29024       122         2018      0.916667     0.833333
# ...         ...       ...          ...           ...          ...
# 7250      36270        65         2018      0.583333     0.900000
# 7251      36271        28         2018      0.750000     0.600000
# 7252      36272       116         2018      0.166667     0.933333
# 7253      36273       148         2018      0.583333     0.033333
# 7254      36274        63         2018      0.333333     0.700000
#
#       NumWeekendNights  NumWeekNights      MealPlan  Parking     RoomType  \
# 0                    0              2   Meal Plan 1        0  Room_Type 1
# 1                    0              4   Meal Plan 1        0  Room_Type 1
# 2                    2              1  Not Selected        0  Room_Type 1
# 3                    0              2   Meal Plan 2        0  Room_Type 1
# 4                    0              1   Meal Plan 1        0  Room_Type 1
# ...                ...            ...           ...      ...          ...
# 7250                 0              3   Meal Plan 1        0  Room_Type 6
# 7251                 2              0   Meal Plan 1        0  Room_Type 1
# 7252                 2              1   Meal Plan 1        0  Room_Type 1
# 7253                 2              6   Meal Plan 1        0  Room_Type 1
# 7254                 0              3  Not Selected        0  Room_Type 1
#
#       NumAdults  NumChildren MarketSegment  RepeatedGuest  \
# 0             2            0        Online              0
# 1             3            0       Offline              0
# 2             2            0        Online              0
# 3             2            0        Online              0
# 4             1            0     Corporate              0
# ...         ...          ...           ...            ...
# 7250          2            2        Online              0
# 7251          2            0        Online              0
# 7252          1            0        Online              0
# 7253          2            0        Online              0
# 7254          2            0        Online              0
#
#       NumPrevCancellations  NumPreviousNonCancelled  AvgRoomPrice  \
# 0                        0                        0        100.00
# 1                        0                        0         96.90
# 2                        0                        0         88.00
# 3                        0                        0        115.00
# 4                        0                        0         67.00
# ...                    ...                      ...           ...
# 7250                     0                        0        177.30
# 7251                     0                        0        149.00
# 7252                     0                        0          1.00
# 7253                     0                        0         98.39
# 7254                     0                        0         94.50
#
#       SpecialRequests  BookingStatus
# 0                   0            NaN
# 1                   1            NaN
# 2                   0            NaN
# 3                   1            NaN
# 4                   0            NaN
# ...               ...            ...
# 7250                0            NaN
# 7251                1            NaN
# 7252                0            NaN
# 7253                2            NaN
# 7254                0            NaN
#
# [7255 rows x 19 columns]
